# %% [markdown]
# # FLipkart Review Scrapping Project

# %%
import sys
import platform
print(f"Executable Python: {sys.executable}")
print(f"Python Version: {platform.python_version()}")

import os

from flask import Flask, render_template, request, jsonify
from flask_cors import CORS, cross_origin
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen as uReq


#To show multiple outputs and misc. changes
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all" # Show all results without print (last_expr)
# Out:
# Executable Python: C:\Users\maity\.conda\envs\review_scrapper\python.exe
# Python Version: 3.9.7

# %%
flipkart_url = "https://www.flipkart.com/search?q=" + "Samsung" #created a url

# %%
flipkart_url
# Out:
# 'https://www.flipkart.com/search?q=Samsung'

# %%
uClient = uReq(flipkart_url) # asks the programm to open the url

# %%
uClient

# %%
flipkartPage = uClient.read() # to read the url that has opened in previous step
flipkartPage[:100]
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="preconnect"/><'

# %%
 uClient.close()

# %%
 flipkart_html = bs(flipkartPage, "html.parser")#parsing the url as html
 flipkart_html
# Out:
# <!DOCTYPE html>
# ...

# %%
bigboxes = flipkart_html.findAll("div", {"class": "_2kHMtA"})
bigboxes[0]
print(len(bigboxes))
# Out:
# <div class="_2kHMtA"><a class="_1fQZEK" href="/samsung-galaxy-f12-sky-blue-64-gb/p/itm0319ce24f74aa?pid=MOBGFG79BVGDHGWV&amp;lid=LSTMOBGFG79BVGDHGWVGF2CRI&amp;marketplace=FLIPKART&amp;q=Samsung&amp;store=tyy%2F4io&amp;srno=s_1_1&amp;otracker=search&amp;fm=organic&amp;iid=f9e40cb0-a294-4bc5-8492-96b08ccefb42.MOBGFG79BVGDHGWV.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=dx6oocosz40000001641775895335&amp;qH=3910b1e0ccab19bc" rel="noopener noreferrer" target="_blank"><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="SAMSUNG Galaxy F12 (Sky Blue, 64 GB)" class="_396cs4 _3exPp9" src="https://rukminim1.flixcart.com/image/312/312/kn22m4w0/mobile/9/k/s/galaxy-f12-sm-f127glbiins-samsung-original-imagftmhhhvghq7w.jpeg?q=70"/></div></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A4_V"><label class="_2iDkf8"><input class="_30VH1S" readonly="" type="checkbox"/><div class="_24_Dny"></div></label></span><label class="_6Up2s
# ...
