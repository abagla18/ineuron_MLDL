# %%
import sys
import platform
import pandas as pd
print(f"Executable Python: {sys.executable}")
print(f"Python Version: {platform.python_version()}")

#To show multiple outputs and misc. changes
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all" # Show all results without print (last_expr)
# Out:
# Executable Python: C:\Users\maity\.conda\envs\aku_mldl\python.exe
# Python Version: 3.9.6

# %%
df_movie= pd.read_csv('G:\My Drive\Coursera\movie_data.csv')
df_movie
# Out:
#                                    Movie Title Release Date  \
# 0                          10 Cloverfield Lane   2016-03-08
# 1    13 Hours: The Secret Soldiers of Benghazi   2016-01-15
# 2                                       2 Guns   2013-08-02
# 3                               21 Jump Street   2012-03-16
# 4                               22 Jump Street   2014-06-04
# ..                                         ...          ...
# 503                 X-Men: Days of Future Past   2014-05-10
# 504                                You're Next   2013-08-23
# 505                           Zero Dark Thirty   2012-12-19
# 506  Zhong Kui: Snow Girl and the Dark Crystal   2015-02-19
# 507                                Zoolander 2   2016-02-12
#
#                                          Wikipedia URL     Genre  \
# 0    https://en.wikipedia.org/wiki/10_Cloverfield_Lane  Thriller
# 1    https://en.wikipedia.org/wiki/13_Hours:_The_Se...    Action
# ...

# %%
df_movie['Revenue'].max()
# Out:
# '$99,800,000.00'

# %%
df_movie['Movie Title'][df_movie['Genre']=='Thriller']
# Out:
# 0        10 Cloverfield Lane
# 14         A Most Wanted Man
# 88             Don't Breathe
# 106           Eye in the Sky
# 220                    Nerve
# 228                 Non-Stop
# 230         Now You See Me 2
# 241    Paranormal Activity 4
# 352            The Conjuring
# 364            The Equalizer
# 371                 The Gift
# 376               The Gunman
# 416         The November Man
# 421          The Perfect Guy
# 431                The Raven
# 432             The Revenant
# Name: Movie Title, dtype: object

# %%
df_movie.fillna(0,inplace =True)

# %%
rows ,columns = df_movie.shape

# %%
rows
columns
# Out:
# 508
# 13

# %%
df_movie.head(2)
# Out:
#                                  Movie Title Release Date  \
# 0                        10 Cloverfield Lane   2016-03-08
# 1  13 Hours: The Secret Soldiers of Benghazi   2016-01-15
#
#                                        Wikipedia URL     Genre  \
# 0  https://en.wikipedia.org/wiki/10_Cloverfield_Lane  Thriller
# 1  https://en.wikipedia.org/wiki/13_Hours:_The_Se...    Action
#
#        Director (1) Director (2)                 Cast (1)        Cast (2)  \
# 0  Dan Trachtenberg            0  Mary Elizabeth Winstead    John Goodman
# 1       Michael Bay            0         James Badge Dale  John Krasinski
#
#          Cast (3)         Cast (4)     Cast (5)         Budget   \
# 0  John Gallagher                0            0  $15,000,000.00
# 1   Toby Stephens  Pablo Schreiber  Max Martini  $45,000,000.00
#
#            Revenue
# 0  $108,300,000.00
# 1   $69,400,000.00

# %%
df_movie.tail(5)
# Out:
#                                    Movie Title Release Date  \
# 503                 X-Men: Days of Future Past   2014-05-10
# 504                                You're Next   2013-08-23
# 505                           Zero Dark Thirty   2012-12-19
# 506  Zhong Kui: Snow Girl and the Dark Crystal   2015-02-19
# 507                                Zoolander 2   2016-02-12
#
#                                          Wikipedia URL    Genre  \
# 503  https://en.wikipedia.org/wiki/X-Men:_Days_of_F...   Action
# 504      https://en.wikipedia.org/wiki/You%2527re_Next   Horror
# 505     https://en.wikipedia.org/wiki/Zero_Dark_Thirty    Drama
# 506  https://en.wikipedia.org/wiki/Zhong_Kui:_Snow_...  Romance
# 507          https://en.wikipedia.org/wiki/Zoolander_2   Comedy
#
#         Director (1) Director (2)          Cast (1)      Cast (2)  \
# 503     Bryan Singer            0      Hugh Jackman  James McAvoy
# 504     Adam Wingard            0     Sharni Vinson  Joe Swanberg
# ...

# %%
df_movie.columns
# Out:
# Index(['Movie Title', 'Release Date', 'Wikipedia URL', 'Genre', 'Director (1)',
#        'Director (2)', 'Cast (1)', 'Cast (2)', 'Cast (3)', 'Cast (4)',
#        'Cast (5)', 'Budget ', 'Revenue'],
#       dtype='object')

# %%
df_movie.Genre.head()
# Out:
# 0    Thriller
# 1      Action
# 2      Action
# 3      Comedy
# 4      Action
# Name: Genre, dtype: object

# %%
df_movie['Genre'].unique( )
# Out:
# array(['Thriller', 'Action', 'Comedy', 'Biography', 'Drama', 'Crime',
#        'Adventure', 'Horror', 'Sci-Fi', 'Romance', 'Musical', 'Fantasy',
#        'Mystery', 'Family', 'Religious', 'Animation', 'Documentary'],
#       dtype=object)

# %%
type(df_movie['Release Date'])
# Out:
# pandas.core.series.Series

# %%
df_movie[['Release Date','Genre']].head(2)
# Out:
#   Release Date     Genre
# 0   2016-03-08  Thriller
# 1   2016-01-15    Action

# %%
df_movie['Release Date'].max()
# Out:
# '2016-08-26'

# %%
df_movie.describe()
# Out:
#                 Movie Title Release Date  \
# count                   508          508
# unique                  508          330
# top     10 Cloverfield Lane   2015-12-25
# freq                      1            6
#
#                                             Wikipedia URL   Genre  \
# count                                                 508     508
# unique                                                508      17
# top     https://en.wikipedia.org/wiki/10_Cloverfield_Lane  Action
# freq                                                    1     120
#
#        Director (1)  Director (2)    Cast (1)  Cast (2)  Cast (3)  Cast (4)  \
# count           508           508         508       508       508       508
# unique          414            40         345       403       413       408
# top      David Ayer             0  Tom Cruise         0         0         0
# freq              4           467           5         5        23        56
#
# ...

# %%
df_movie[df_movie.Genre == 'Action'].head()
# Out:
#                                  Movie Title Release Date  \
# 1  13 Hours: The Secret Soldiers of Benghazi   2016-01-15
# 2                                     2 Guns   2013-08-02
# 4                             22 Jump Street   2014-06-04
# 5                     300: Rise of an Empire   2014-03-04
# 7                                         71   2014-02-07
#
#                                        Wikipedia URL   Genre  \
# 1  https://en.wikipedia.org/wiki/13_Hours:_The_Se...  Action
# 2               https://en.wikipedia.org/wiki/2_Guns  Action
# 4       https://en.wikipedia.org/wiki/22_Jump_Street  Action
# 5  https://en.wikipedia.org/wiki/300:_Rise_of_an_...  Action
# 7       https://en.wikipedia.org/wiki/%252771_(film)  Action
#
#         Director (1)  Director (2)          Cast (1)           Cast (2)  \
# 1        Michael Bay             0  James Badge Dale     John Krasinski
# 2  Baltasar Kormákur             0     Mark Wahlberg  Denzel Washington
# ...

# %%
filter1 = df_movie['Release Date']==df_movie['Release Date'].max()
df_movie[filter1][["Genre","Release Date"]]
# Out:
#          Genre Release Date
# 88    Thriller   2016-08-26
# 132  Biography   2016-08-26
# 200     Action   2016-08-26

# %%
df1=df_movie.set_index('Movie Title')

# %%
df1.loc['Zoolander 2']
# Out:
# Release Date                                    2016-02-12
# Wikipedia URL    https://en.wikipedia.org/wiki/Zoolander_2
# Genre                                               Comedy
# Director (1)                                   Ben Stiller
# Director (2)                                             0
# Cast (1)                                       Ben Stiller
# Cast (2)                                       Owen Wilson
# Cast (3)                                  Christine Taylor
# Cast (4)                                      Will Ferrell
# Cast (5)                                     Penélope Cruz
# Budget                                      $50,000,000.00
# Revenue                                     $56,000,000.00
# Name: Zoolander 2, dtype: object

# %%
# loading a dataframe by pasing a dictionary
weather_data = {'day':['1/1/2017','1/2/2017','1/3/2017'],
                'temperature': [32,35,28],
                'windspeed':[6,7,2],
                'event':['Rain','Snow','Sunny']}
df = pd.DataFrame(weather_data)
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7   Snow
# 2  1/3/2017           28          2  Sunny

# %%
# loading dataframe by pasing a list of tuples
weather_data = [('1/1/2017',32,6,"Rain"),
                ('1/2/2017',35,7,"Sunny"),
                ('1/3/2017',28,2,"Snow")]

df= pd.DataFrame(weather_data,columns = ["date","Temperature","windspeed","event"])
df
# Out:
#        date  Temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %%
df_stocks = pd.DataFrame({
    'Ticker':['Google',"WMT","MSFT"],
    'Price':[845,65,64],
    'Pe': [ 30.37,14.26,30.97],
    'Eps':[27.82,4.61,2.12]

})

df_weather = pd.DataFrame({
                'day':['1/1/2017','1/2/2017','1/3/2017'],
                'temperature': [32,35,28],
                'windspeed':[6,7,2],
                'event':['Rain','Snow','Sunny']
})

# %%
with pd.ExcelWriter('Stocks_weather.xlsx') as writer:
    df_stocks.to_excel(writer,sheet_name='Stocks',index=False)
    df_weather.to_excel(writer,sheet_name = 'Weather',index=False)

# %%
df1 = pd.read_excel('Stocks_weather.xlsx',sheet_name='Weather',parse_dates=['day'])
df1
# Out:
#          day  temperature  windspeed  event
# 0 2017-01-01           32          6   Rain
# 1 2017-01-02           35          7   Snow
# 2 2017-01-03           28          2  Sunny

# %%
df1.set_index('day',inplace=True)

# %%
df1
# Out:
#             temperature  windspeed  event
# day
# 2017-01-01           32          6   Rain
# 2017-01-02           35          7   Snow
# 2017-01-03           28          2  Sunny

# %%
new_df= df1.fillna({
    'temperature': 0,
    'windspeed': 0,
    'event': 'No event'
})

# %%
new_df
# Out:
#             temperature  windspeed  event
# day
# 2017-01-01           32          6   Rain
# 2017-01-02           35          7   Snow
# 2017-01-03           28          2  Sunny

# %%
new_df= df1.fillna(method='ffill')
new_df
# Out:
#             temperature  windspeed  event
# day
# 2017-01-01           32          6   Rain
# 2017-01-02           35          7   Snow
# 2017-01-03           28          2  Sunny

# %%
df_movie.head()
# Out:
#                                  Movie Title Release Date  \
# 0                        10 Cloverfield Lane   2016-03-08
# 1  13 Hours: The Secret Soldiers of Benghazi   2016-01-15
# 2                                     2 Guns   2013-08-02
# 3                             21 Jump Street   2012-03-16
# 4                             22 Jump Street   2014-06-04
#
#                                        Wikipedia URL     Genre  \
# 0  https://en.wikipedia.org/wiki/10_Cloverfield_Lane  Thriller
# 1  https://en.wikipedia.org/wiki/13_Hours:_The_Se...    Action
# 2               https://en.wikipedia.org/wiki/2_Guns    Action
# 3  https://en.wikipedia.org/wiki/21_Jump_Street_(...    Comedy
# 4       https://en.wikipedia.org/wiki/22_Jump_Street    Action
#
#         Director (1)  Director (2)                 Cast (1)  \
# 0   Dan Trachtenberg             0  Mary Elizabeth Winstead
# 1        Michael Bay             0         James Badge Dale
# ...

# %%
g = df_movie.groupby('Genre')
g

# %%
for Genre,Genre_df in g:
    print(Genre)
    print(Genre_df)
# Out:
# Action
#                                    Movie Title Release Date  \
# 1    13 Hours: The Secret Soldiers of Benghazi   2016-01-15
# 2                                       2 Guns   2013-08-02
# 4                               22 Jump Street   2014-06-04
# 5                       300: Rise of an Empire   2014-03-04
# 7                                           71   2014-02-07
# ..                                         ...          ...
# 493                           White House Down   2013-06-28
# 500                                World War Z   2013-06-21
# 501                        Wrath of the Titans   2012-03-30
# 502                          X-Men: Apocalypse   2016-05-09
# 503                 X-Men: Days of Future Past   2014-05-10
#
#                                          Wikipedia URL   Genre  \
# 1    https://en.wikipedia.org/wiki/13_Hours:_The_Se...  Action
# 2                 https://en.wikipedia.org/wiki/2_Guns  Action
# ...

# %%
g.get_group('Comedy')
# Out:
#                               Movie Title Release Date  \
# 3                          21 Jump Street   2012-03-16
# 10                        A Haunted House   2013-01-11
# 11                      A Haunted House 2   2014-04-18
# 12                        A Long Way Down   2014-02-10
# 15                       A Thousand Words   2012-03-09
# ..                                    ...          ...
# 477                   Unfinished Business   2015-03-06
# 483                            Wanderlust   2012-02-24
# 487                           Warm Bodies   2013-02-01
# 489  What to Expect When You're Expecting   2012-05-18
# 507                           Zoolander 2   2016-02-12
#
#                                          Wikipedia URL   Genre  \
# 3    https://en.wikipedia.org/wiki/21_Jump_Street_(...  Comedy
# 10   https://en.wikipedia.org/wiki/A_Haunted_House_...  Comedy
# 11     https://en.wikipedia.org/wiki/A_Haunted_House_2  Comedy
# ...

# %%
g.max()
# Out:
# C:\Users\maity\AppData\Local\Temp/ipykernel_18240/557829741.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   g.max()
#                                              Movie Title Release Date  \
# Genre
# Action                        X-Men: Days of Future Past   2016-08-26
# Adventure                                       Vacation   2016-08-19
# Animation                              The Peanuts Movie   2015-11-01
# Biography                                       The Walk   2016-08-26
# Comedy                                       Zoolander 2   2016-08-05
# Crime                                           War Dogs   2016-08-19
# Documentary                    One Direction: This Is Us   2013-08-29
# Drama                                   Zero Dark Thirty   2016-07-13
# ...

# %%
g.min()
# Out:
# C:\Users\maity\AppData\Local\Temp/ipykernel_18240/3597954327.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.min is deprecated. In a future version, a TypeError will be raised. Before calling .min, select only columns which should be valid for the function.
#   g.min()
#                                            Movie Title Release Date  \
# Genre
# Action       13 Hours: The Secret Soldiers of Benghazi   2012-01-27
# Adventure                          A Walk in the Woods   2012-02-10
# Animation                                         Home   2014-08-08
# Biography                                           42   2012-10-26
# Comedy                                  21 Jump Street   2012-02-24
# Crime                      A Walk Among the Tombstones   2012-01-27
# Documentary                  One Direction: This Is Us   2013-08-29
# Drama                             90 Minutes in Heaven   2012-01-20
# ...

# %%
g.mean()
# Out:
# Empty DataFrame
# Columns: []
# Index: [Action, Adventure, Animation, Biography, Comedy, Crime, Documentary, Drama, Family, Fantasy, Horror, Musical, Mystery, Religious, Romance, Sci-Fi, Thriller]

# %%
india_weather= pd.DataFrame({
    'city':["mumbai","delhi","banglore"],
    'temperature':[32,45,30],
    "humidity":[80,60,78]
})
india_weather
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           45        60
# 2  banglore           30        78

# %%
US_weather= pd.DataFrame({
    'city':["new york","chicago","orlando"],
    'temperature':[21,14,35],
    "humidity":[68,78,75]
})
US_weather
# Out:
#        city  temperature  humidity
# 0  new york           21        68
# 1   chicago           14        78
# 2   orlando           35        75

# %%
df_city = pd.concat([india_weather,US_weather],ignore_index=True)
df_city
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           45        60
# 2  banglore           30        78
# 3  new york           21        68
# 4   chicago           14        78
# 5   orlando           35        75

# %%
df_city = pd.concat([india_weather,US_weather], keys=["india","US"])
df_city
# Out:
#              city  temperature  humidity
# india 0    mumbai           32        80
#       1     delhi           45        60
#       2  banglore           30        78
# US    0  new york           21        68
#       1   chicago           14        78
#       2   orlando           35        75

# %%
df_city.loc["india"]
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           45        60
# 2  banglore           30        78

# %%
df_temp= pd.DataFrame({
    'city':["new york","chicago","orlando"],
    'temperature':[21,14,35]
    })
df_temp
# Out:
#        city  temperature
# 0  new york           21
# 1   chicago           14
# 2   orlando           35

# %%
df_windspeed =pd.DataFrame({
    'city':["new york","chicago","orlando"],
    'windspeed':[25,40,12]
    })
df_windspeed
# Out:
#        city  windspeed
# 0  new york         25
# 1   chicago         40
# 2   orlando         12

# %%
df5=pd.concat([df_temp,df_windspeed],axis=1,)
df5
# Out:
#        city  temperature      city  windspeed
# 0  new york           21  new york         25
# 1   chicago           14   chicago         40
# 2   orlando           35   orlando         12

# %%
s=pd.Series(['Rain',"dry","sunny"],name = "event")
s
# Out:
# 0     Rain
# 1      dry
# 2    sunny
# Name: event, dtype: object

# %%
df6 = pd.concat([df_temp,s],axis = 1)
df6
# Out:
#        city  temperature  event
# 0  new york           21   Rain
# 1   chicago           14    dry
# 2   orlando           35  sunny

# %%
df_humidity =pd.DataFrame({
    'city':["new york","chicago","orlando"],
    "humidity":[68,78,75]
    })
df_humidity
# Out:
#        city  humidity
# 0  new york        68
# 1   chicago        78
# 2   orlando        75

# %%
df7=pd.merge(df_temp,df_humidity,on="city",how="inner",indicator=True)
df7
# Out:
#        city  temperature  humidity _merge
# 0  new york           21        68   both
# 1   chicago           14        78   both
# 2   orlando           35        75   both

# %%
df6.pivot(index='city',columns='event')
# Out:
#          temperature
# event           Rain   dry sunny
# city
# chicago          NaN  14.0   NaN
# new york        21.0   NaN   NaN
# orlando          NaN   NaN  35.0

# %%
df_city
# Out:
#              city  temperature  humidity
# india 0    mumbai           32        80
#       1     delhi           45        60
#       2  banglore           30        78
# US    0  new york           21        68
#       1   chicago           14        78
#       2   orlando           35        75

# %%
df_city.pivot_table(index='city',columns='temperature')
# Out:
#             humidity
# temperature       14    21    30    32    35    45
# city
# banglore         NaN   NaN  78.0   NaN   NaN   NaN
# chicago         78.0   NaN   NaN   NaN   NaN   NaN
# delhi            NaN   NaN   NaN   NaN   NaN  60.0
# mumbai           NaN   NaN   NaN  80.0   NaN   NaN
# new york         NaN  68.0   NaN   NaN   NaN   NaN
# orlando          NaN   NaN   NaN   NaN  75.0   NaN

# %%
# df_city["date"]=pd.to_datetime(df_city['date])

# df_city.pivot_table(index=pd.Grouper(freq='M',key='Date'),columns = 'city')
